# %%
from IPython.display import display, Markdown

math = [80, 92, 75, 60, 88]
physics = [70, 65, 90, 85, 78]
english = [95, 100, 85, 90, 87]

avg_math = sum(math) / len(math)
avg_physics = sum(physics) / len(physics)
avg_english = sum(english) / len(english)

if avg_math > avg_physics and avg_math > avg_english:
    best_subject = "Math"
elif avg_physics > avg_english:
    best_subject = "Physics"
else:
    best_subject = "English"

display(Markdown(f"""
## Results

| # | Average | Max | Min |
|---|---|---|---|
| Math | {sum(math)} | {max(math)} | {min(math)} |
| Physics | {avg_physics} | {max(physics)} | {min(physics)} |
| English | {avg_english} | {max(english)} | {min(english)} |
"""))
# Out:
# ## Results
#
# | # | Average | Max | Min |
# |---|---|---|---|
# | Math | 395 | 92 | 60 |
# | Physics | 77.6 | 90 | 65 |
# | English | 91.4 | 100 | 85 |
